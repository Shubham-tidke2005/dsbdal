# %% [markdown]
# 1. Locate open Iris dataset from the URL csv_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
# 2. Perform the Dummy Variable Encoding , by considering Species as target variable.

# %%
import pandas as pd   
import numpy as np          
import seaborn as sns      
import matplotlib.pyplot as plt

# %%
url="https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"

# %%
df=pd.read_csv(url,header=None,names=["sep_len","sep_wid","pet_len","pet_wid","spe"])
df.head(5)
# Out:
#    sep_len  sep_wid  pet_len  pet_wid          spe
# 0      5.1      3.5      1.4      0.2  Iris-setosa
# 1      4.9      3.0      1.4      0.2  Iris-setosa
# 2      4.7      3.2      1.3      0.2  Iris-setosa
# 3      4.6      3.1      1.5      0.2  Iris-setosa
# 4      5.0      3.6      1.4      0.2  Iris-setosa

# %%
encode_df=pd.get_dummies(df,columns=["spe"],drop_first=True)

# %%
encode_df.head(10)
# Out:
#    sep_len  sep_wid  pet_len  pet_wid  spe_Iris-versicolor  spe_Iris-virginica
# 0      5.1      3.5      1.4      0.2                False               False
# 1      4.9      3.0      1.4      0.2                False               False
# 2      4.7      3.2      1.3      0.2                False               False
# 3      4.6      3.1      1.5      0.2                False               False
# 4      5.0      3.6      1.4      0.2                False               False
# 5      5.4      3.9      1.7      0.4                False               False
# 6      4.6      3.4      1.4      0.3                False               False
# 7      5.0      3.4      1.5      0.2                False               False
# 8      4.4      2.9      1.4      0.2                False               False
# 9      4.9      3.1      1.5      0.1                False               False

# %%
encode_df.head(10)
# Out:
#    sep_len  sep_wid  pet_len  pet_wid  spe_Iris-versicolor  spe_Iris-virginica
# 0      5.1      3.5      1.4      0.2                False               False
# 1      4.9      3.0      1.4      0.2                False               False
# 2      4.7      3.2      1.3      0.2                False               False
# 3      4.6      3.1      1.5      0.2                False               False
# 4      5.0      3.6      1.4      0.2                False               False
# 5      5.4      3.9      1.7      0.4                False               False
# 6      4.6      3.4      1.4      0.3                False               False
# 7      5.0      3.4      1.5      0.2                False               False
# 8      4.4      2.9      1.4      0.2                False               False
# 9      4.9      3.1      1.5      0.1                False               False
