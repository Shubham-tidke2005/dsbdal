# %%
import pandas as pd   
import numpy as np          
import seaborn as sns      
import matplotlib.pyplot as plt

# %%
url="https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"

# %%
df=pd.read_csv(url,header=None,names=["sep_len","sep_wid","pet_len","pet_wid","spe"])
df.head(5)
# Out:
#    sep_len  sep_wid  pet_len  pet_wid          spe
# 0      5.1      3.5      1.4      0.2  Iris-setosa
# 1      4.9      3.0      1.4      0.2  Iris-setosa
# 2      4.7      3.2      1.3      0.2  Iris-setosa
# 3      4.6      3.1      1.5      0.2  Iris-setosa
# 4      5.0      3.6      1.4      0.2  Iris-setosa

# %%
encode_df=pd.get_dummies(df,columns=["spe"])

# %%
encode_df.head(10)
# Out:
#    sep_len  sep_wid  pet_len  pet_wid  spe_Iris-setosa  spe_Iris-versicolor  \
# 0      5.1      3.5      1.4      0.2             True                False
# 1      4.9      3.0      1.4      0.2             True                False
# 2      4.7      3.2      1.3      0.2             True                False
# 3      4.6      3.1      1.5      0.2             True                False
# 4      5.0      3.6      1.4      0.2             True                False
# 5      5.4      3.9      1.7      0.4             True                False
# 6      4.6      3.4      1.4      0.3             True                False
# 7      5.0      3.4      1.5      0.2             True                False
# 8      4.4      2.9      1.4      0.2             True                False
# 9      4.9      3.1      1.5      0.1             True                False
#
#    spe_Iris-virginica
# 0               False
# 1               False
# 2               False
# 3               False
# 4               False
# 5               False
# 6               False
# 7               False
# 8               False
# 9               False

# %%
# Out:
# array([0, 1, 2])
